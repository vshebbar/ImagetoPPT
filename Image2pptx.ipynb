# %%
##
##  Copy & Paste Tool for images to PowerPoint(.pptx)
##
import pptx
import pptx.util
import glob
import scipy.misc

OUTPUT_TAG = "MyImagePPT"

# new
prs = pptx.Presentation()
# open
# prs_exists = pptx.Presentation("some_presentation.pptx")

# default slide width
#prs.slide_width = 9144000
# slide height @ 4:3
#prs.slide_height = 6858000
# slide height @ 16:9
prs.slide_height = 5143500

# title slide
slide = prs.slides.add_slide(prs.slide_layouts[0])
# blank slide
#slide = prs.slides.add_slide(prs.slide_layouts[6])

# set title
title = slide.shapes.title
title.text = OUTPUT_TAG

pic_left  = int(prs.slide_width * 0.15)
pic_top   = int(prs.slide_height * 0.1)
pic_width = int(prs.slide_width * 0.7)

for g in glob.glob("/Users/manas/Documents/RandomNotes_DL/*"):
    print(g)
    slide = prs.slides.add_slide(prs.slide_layouts[6])

    tb = slide.shapes.add_textbox(0, 0, prs.slide_width, pic_top / 2)
    p = tb.text_frame.add_paragraph()
    p.text = g
    p.font.size = pptx.util.Pt(14)

    img = scipy.misc.imread(g)
    pic_height = int(pic_width * img.shape[0] / img.shape[1])
    #pic   = slide.shapes.add_picture(g, pic_left, pic_top)
    pic   = slide.shapes.add_picture(g, pic_left, pic_top, pic_width, pic_height)

prs.save("%s.pptx" % OUTPUT_TAG)
print('saved')
# Out:
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-23 at 3.53.59 PM.png
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:45: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-23 at 3.54.26 PM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-23 at 3.55.02 PM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-23 at 3.56.49 PM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-23 at 3.57.06 PM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 10.28.24 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 10.28.39 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 10.28.59 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 10.29.11 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 10.29.20 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 10.30.17 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 10.43.19 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 10.44.14 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 10.45.20 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 10.45.39 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 11.04.02 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 11.05.07 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 11.05.47 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 11.06.29 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 11.06.59 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 11.07.14 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 11.07.31 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 11.07.56 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 11.08.04 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 11.08.35 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 11.22.35 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 11.22.48 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 11.22.57 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 11.23.09 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 11.23.18 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 11.23.24 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 11.23.32 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 11.23.42 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 11.23.51 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 11.24.03 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 11.24.37 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 11.24.46 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 11.25.02 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 11.45.43 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 11.45.50 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 11.46.02 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 11.46.18 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 11.46.40 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 11.52.55 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 11.53.11 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 11.56.13 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 11.56.20 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 11.57.07 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 11.57.36 AM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 12.22.34 PM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 12.22.50 PM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 12.27.37 PM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 12.28.04 PM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 12.38.42 PM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 12.54.03 PM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 12.54.13 PM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 12.54.30 PM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 12.55.01 PM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 12.55.17 PM.png
# /Users/manas/Documents/RandomNotes_DL/Screen Shot 2018-06-28 at 12.59.35 PM.png
# saved
